# %%
import pandas as pd

# %%
books = pd.read_csv(path,usecols=['isbn10','title','author_first','author_last','categories','thumbnail','published_year','num_pages'] )

# %%
books.to_csv('books.csv')

# %%
books
# Out:
#         isbn10                                              title  \
# 0   0439554934     Harry Potter and the Sorcerer's Stone (Book 1)
# 1   0316015849                                           Twilight
# 2   0618260307               The Hobbit, Or, There and Back Again
# 3   1416524797                                    Angels & Demons
# 4   043965548X  Harry Potter and the Prisoner of Azkaban (Book 3)
# ..         ...                                                ...
# 94  0446696617                                         1st to Die
# 95  0439227143                               The Call of the Wild
# 96  0590032496                                        The witches
# 97  0451216954                                         Dark Lover
# 98  0552135399                            A Prayer for Owen Meany
#
#    author_first author_last           categories  \
# 0          J.K.     Rowling     Juvenile Fiction
# 1     Stephenie       Meyer  Young Adult Fiction
# ...
